# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# sphinx_gallery_thumbnail_number = 2

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


df = pd.read_excel('hyperparametersAndF1.xlsx')
print(df['depth'])

farmers = range(1, 21)
vegetables = range(1,21)
dfF1 = df['f1']
f1 = np.zeros(400).reshape(20, 20)

for i in range(400):
    row = i//20
    column = i - (row*20)
    f1[row][column] = dfF1[i]
    
    
harvest = f1
print(f1)

fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i][j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       5
# 18       5
# 19       5
# 20      10
# 21      10
# 22      10
# 23      10
# 24      10
# 25      10
# 26      10
# 27      10
# 28      10
# 29      10
#       ...
# 370     95
# 371     95
# 372     95
# 373     95
# 374     95
# 375     95
# 376     95
# 377     95
# 378     95
# 379     95
# 380    100
# 381    100
# 382    100
# 383    100
# 384    100
# 385    100
# 386    100
# 387    100
# 388    100
# 389    100
# 390    100
# 391    100
# 392    100
# 393    100
# 394    100
# 395    100
# 396    100
# 397    100
# 398    100
# 399    100
# Name: depth, Length: 400, dtype: int64
# [[0.71258049 0.70037114 0.72955654 0.73398297 0.73745401 0.71705753
#   0.73199744 0.75755551 0.76622639 0.75951842 0.75908271 0.72657351
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# a 2D array with linearly increasing values on the diagonal
df = pd.read_excel('hyperparametersAndF1.xlsx')
print(df['depth'])

dfF1 = df['f1']
f1 = np.zeros(380).reshape(19, 20)

for i in range(380):
    row = i//20
    column = i - (row*20)
    f1[row][column] = dfF1[i]
print(f1)

plt.matshow(f1)
plt.xlabel("Maximum Depth")
plt.ylabel("Number of Estimators")
plt.show()
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
# 5       10
# 6       10
# 7       10
# 8       10
# 9       10
# 10      10
# 11      10
# 12      10
# 13      10
# 14      10
# 15      10
# 16      10
# 17      10
# 18      10
# 19      10
# 20      15
# 21      15
# 22      15
# 23      15
# 24      15
# 25      15
# 26      15
# 27      15
# 28      15
# 29      15
#       ...
# 350     95
# 351     95
# 352     95
# 353     95
# 354     95
# 355     95
# 356     95
# 357     95
# 358     95
# 359     95
# 360    100
# 361    100
# 362    100
# 363    100
# 364    100
# 365    100
# 366    100
# 367    100
# 368    100
# 369    100
# 370    100
# 371    100
# 372    100
# 373    100
# 374    100
# 375    100
# 376    100
# 377    100
# 378    100
# 379    100
# Name: depth, Length: 380, dtype: int64
# [[0.90198028 0.91958862 0.91822436 0.92046377 0.92327855 0.92176255
#   0.92501419 0.92569498 0.9209617  0.92667301 0.92647485 0.92286569
# ...
